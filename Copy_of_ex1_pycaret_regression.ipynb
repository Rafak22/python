# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafak22/python/blob/main/Copy_of_ex1_pycaret_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # M4.Ex1: Housing Prices Model (PyCaret)

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M6/exercises/ex1_pycaret_regression.ipynb)

# %% [markdown]
# ## Exercise
#
# Your task is to follow the steps outlined here, and apply them on the **California Housing Dataset** below:
#
# - [**🚀 Regression**](https://pycaret.gitbook.io/docs/get-started/quickstart#regression)
#     - Setup
#     - Compare Models
#     - Analyze Model
#     - Predictions
#     - Save the model

# %% [markdown]
# ## California Housing Prices Dataset
#
#
# Find and download the dataset from Kaggle at [California Housing Dataset](https://www.kaggle.com/datasets/dhirajnirne/california-housing-data).
#
# According to [keras.io](https://keras.io/api/datasets/california_housing/):
#
# > This dataset was obtained from the StatLib repository.
# >
# > It's a continuous regression dataset with 20,640 samples with 8 features each.
# >
# > The target variable is a scalar: the median house value for California districts, in dollars.
# >
# > The 8 input features are the following:
# >
# > - MedInc: median income in block group
# > - HouseAge: median house age in block group
# > - AveRooms: average number of rooms per household
# > - AveBedrms: average number of bedrooms per household
# > - Population: block group population
# > - AveOccup: average number of household members
# > - Latitude: block group latitude
# > - Longitude: block group longitude
# >
# > This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
# >
# > A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surprisingly large values for block groups with few households and many empty houses, such as vacation resorts.

# %% [markdown]
# ### Load the data

# %% [markdown]
# **Task**: Your model should learn from this data and be able to predict the median housing price (`median_house_value`) in any district, given all the other metrics.
#
# Please read the above dataset description to understand what the features mean.

# %%
# !pip install numpy==1.26.4 -q

# %%
# !pip install git+https://github.com/pycaret/pycaret.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
clean_content = '''import sys
from pycaret.utils._show_versions import show_versions

version_ = "3.3.2"

__version__ = version_

__all__ = ["show_versions", "__version__"]

if sys.version_info < (3, 9):
    raise RuntimeError(
        sys.version_info,
        "Please UPGRADE your Python version.",
    )
'''

with open('/usr/local/lib/python3.12/dist-packages/pycaret/__init__.py', 'w') as f:
    f.write(clean_content)

print("Fixed!")
# Out:
# Fixed!

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
from pycaret.regression import *

s = setup(df, target='median_house_value', session_id=123)
# Out:
# <style type="text/css">
# #T_78e57_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78e57" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78e57_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78e57_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78e57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78e57_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78e57_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78e57_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78e57_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78e57_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_78e57_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78e57_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_78e57_row3_col1" class="data row3 col1" >(20640, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78e57_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_78e57_row4_col1" class="data row4 col1" >(20640, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78e57_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_78e57_row5_col1" class="data row5 col1" >(14447, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78e57_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_78e57_row6_col1" class="data row6 col1" >(6193, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78e57_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_78e57_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78e57_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_78e57_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78e57_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_78e57_row9_col1" class="data row9 col1" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_78e57_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_78e57_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_78e57_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_78e57_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_78e57_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_78e57_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_78e57_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_78e57_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_78e57_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_78e57_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_78e57_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_78e57_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_78e57_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_78e57_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_78e57_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_78e57_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_78e57_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_78e57_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_78e57_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_78e57_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_78e57_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_78e57_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_78e57_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_78e57_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_78e57_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_78e57_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_78e57_row22_col1" class="data row22 col1" >bf98</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_a9881 th {
#   text-align: left;
# }
# #T_a9881_row0_col0, #T_a9881_row1_col0, #T_a9881_row1_col1, #T_a9881_row1_col2, #T_a9881_row1_col3, #T_a9881_row1_col4, #T_a9881_row1_col5, #T_a9881_row1_col6, #T_a9881_row2_col0, #T_a9881_row2_col1, #T_a9881_row2_col2, #T_a9881_row2_col3, #T_a9881_row2_col4, #T_a9881_row2_col5, #T_a9881_row2_col6, #T_a9881_row3_col0, #T_a9881_row3_col1, #T_a9881_row3_col2, #T_a9881_row3_col3, #T_a9881_row3_col4, #T_a9881_row3_col5, #T_a9881_row3_col6, #T_a9881_row4_col0, #T_a9881_row4_col1, #T_a9881_row4_col2, #T_a9881_row4_col3, #T_a9881_row4_col4, #T_a9881_row4_col5, #T_a9881_row4_col6, #T_a9881_row5_col0, #T_a9881_row5_col1, #T_a9881_row5_col2, #T_a9881_row5_col3, #T_a9881_row5_col4, #T_a9881_row5_col5, #T_a9881_row5_col6, #T_a9881_row6_col0, #T_a9881_row6_col1, #T_a9881_row6_col2, #T_a9881_row6_col3, #T_a9881_row6_col4, #T_a9881_row6_col5, #T_a9881_row6_col6, #T_a9881_row7_col0, #T_a9881_row7_col1, #T_a9881_row7_col2, #T_a9881_row7_col3, #T_a9881_row7_col4, #T_a9881_row7_col5, #T_a9881_row7_col6, #T_a9881_row8_col0, #T_a9881_row8_col1, #T_a9881_row8_col2, #T_a9881_row8_col3, #T_a9881_row8_col4, #T_a9881_row8_col5, #T_a9881_row8_col6, #T_a9881_row9_col0, #T_a9881_row9_col1, #T_a9881_row9_col2, #T_a9881_row9_col3, #T_a9881_row9_col4, #T_a9881_row9_col5, #T_a9881_row9_col6, #T_a9881_row10_col0, #T_a9881_row10_col1, #T_a9881_row10_col2, #T_a9881_row10_col3, #T_a9881_row10_col4, #T_a9881_row10_col5, #T_a9881_row10_col6, #T_a9881_row11_col0, #T_a9881_row11_col1, #T_a9881_row11_col2, #T_a9881_row11_col3, #T_a9881_row11_col4, #T_a9881_row11_col5, #T_a9881_row11_col6, #T_a9881_row12_col0, #T_a9881_row12_col1, #T_a9881_row12_col2, #T_a9881_row12_col3, #T_a9881_row12_col4, #T_a9881_row12_col5, #T_a9881_row12_col6, #T_a9881_row13_col0, #T_a9881_row13_col1, #T_a9881_row13_col2, #T_a9881_row13_col3, #T_a9881_row13_col4, #T_a9881_row13_col5, #T_a9881_row13_col6, #T_a9881_row14_col0, #T_a9881_row14_col1, #T_a9881_row14_col2, #T_a9881_row14_col3, #T_a9881_row14_col4, #T_a9881_row14_col5, #T_a9881_row14_col6, #T_a9881_row15_col0, #T_a9881_row15_col1, #T_a9881_row15_col2, #T_a9881_row15_col3, #T_a9881_row15_col4, #T_a9881_row15_col5, #T_a9881_row15_col6, #T_a9881_row16_col0, #T_a9881_row16_col1, #T_a9881_row16_col2, #T_a9881_row16_col3, #T_a9881_row16_col4, #T_a9881_row16_col5, #T_a9881_row16_col6, #T_a9881_row17_col0, #T_a9881_row17_col1, #T_a9881_row17_col2, #T_a9881_row17_col3, #T_a9881_row17_col4, #T_a9881_row17_col5, #T_a9881_row17_col6 {
#   text-align: left;
# }
# #T_a9881_row0_col1, #T_a9881_row0_col2, #T_a9881_row0_col3, #T_a9881_row0_col4, #T_a9881_row0_col5, #T_a9881_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a9881_row0_col7, #T_a9881_row1_col7, #T_a9881_row2_col7, #T_a9881_row3_col7, #T_a9881_row4_col7, #T_a9881_row5_col7, #T_a9881_row6_col7, #T_a9881_row7_col7, #T_a9881_row8_col7, #T_a9881_row9_col7, #T_a9881_row10_col7, #T_a9881_row11_col7, #T_a9881_row12_col7, #T_a9881_row13_col7, #T_a9881_row14_col7, #T_a9881_row15_col7, #T_a9881_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a9881_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a9881" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9881_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9881_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a9881_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a9881_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a9881_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a9881_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a9881_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a9881_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9881_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_a9881_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a9881_row0_col1" class="data row0 col1" >32446.5243</td>
#       <td id="T_a9881_row0_col2" class="data row0 col2" >2352506625.5720</td>
#       <td id="T_a9881_row0_col3" class="data row0 col3" >48484.5478</td>
#       <td id="T_a9881_row0_col4" class="data row0 col4" >0.8231</td>
#       <td id="T_a9881_row0_col5" class="data row0 col5" >0.2376</td>
#       <td id="T_a9881_row0_col6" class="data row0 col6" >0.1806</td>
#       <td id="T_a9881_row0_col7" class="data row0 col7" >1.2380</td>
#     </tr>
#     <tr>
#       <th id="T_a9881_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_a9881_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_a9881_row1_col1" class="data row1 col1" >32601.1401</td>
#       <td id="T_a9881_row1_col2" class="data row1 col2" >2500102516.8196</td>
#       <td id="T_a9881_row1_col3" class="data row1 col3" >49989.2760</td>
#       <td id="T_a9881_row1_col4" class="data row1 col4" >0.8121</td>
#       <td id="T_a9881_row1_col5" class="data row1 col5" >0.2415</td>
#       <td id="T_a9881_row1_col6" class="data row1 col6" >0.1817</td>
#       <td id="T_a9881_row1_col7" class="data row1 col7" >12.0070</td>
#     </tr>
#     <tr>
#       <th id="T_a9881_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_a9881_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_a9881_row2_col1" class="data row2 col1" >35279.0180</td>
#       <td id="T_a9881_row2_col2" class="data row2 col2" >2805036753.3820</td>
#       <td id="T_a9881_row2_col3" class="data row2 col3" >52947.4818</td>
#       <td id="T_a9881_row2_col4" class="data row2 col4" >0.7892</td>
#       <td id="T_a9881_row2_col5" class="data row2 col5" >0.2522</td>
#       <td id="T_a9881_row2_col6" class="data row2 col6" >0.1955</td>
#       <td id="T_a9881_row2_col7" class="data row2 col7" >4.6240</td>
#     </tr>
#     <tr>
#       <th id="T_a9881_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_a9881_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a9881_row3_col1" class="data row3 col1" >39009.2448</td>
#       <td id="T_a9881_row3_col2" class="data row3 col2" >3150819000.1502</td>
#       <td id="T_a9881_row3_col3" class="data row3 col3" >56118.7995</td>
#       <td id="T_a9881_row3_col4" class="data row3 col4" >0.7633</td>
#       <td id="T_a9881_row3_col5" class="data row3 col5" >0.2736</td>
#       <td id="T_a9881_row3_col6" class="data row3 col6" >0.2186</td>
#       <td id="T_a9881_row3_col7" class="data row3 col7" >2.8040</td>
#     </tr>
#     <tr>
#       <th id="T_a9881_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_a9881_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_a9881_row4_col1" class="data row4 col1" >50154.1376</td>
#       <td id="T_a9881_row4_col2" class="data row4 col2" >4757779475.9005</td>
#       <td id="T_a9881_row4_col3" class="data row4 col3" >68960.1376</td>
#       <td id="T_a9881_row4_col4" class="data row4 col4" >0.6429</td>
#       <td id="T_a9881_row4_col5" class="data row4 col5" >0.3811</td>
#       <td id="T_a9881_row4_col6" class="data row4 col6" >0.2885</td>
#       <td id="T_a9881_row4_col7" class="data row4 col7" >1.4800</td>
#     </tr>
#     <tr>
#       <th id="T_a9881_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_a9881_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_a9881_row5_col1" class="data row5 col1" >50154.5348</td>
#       <td id="T_a9881_row5_col2" class="data row5 col2" >4757787550.5767</td>
#       <td id="T_a9881_row5_col3" class="data row5 col3" >68960.2055</td>
#       <td id="T_a9881_row5_col4" class="data row5 col4" >0.6429</td>
#       <td id="T_a9881_row5_col5" class="data row5 col5" >0.3811</td>
#       <td id="T_a9881_row5_col6" class="data row5 col6" >0.2885</td>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6076" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6076_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b6076_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b6076_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b6076_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b6076_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b6076_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b6076_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6076_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6076_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b6076_row0_col1" class="data row0 col1" >31369.6739</td>
#       <td id="T_b6076_row0_col2" class="data row0 col2" >2131895630.1813</td>
#       <td id="T_b6076_row0_col3" class="data row0 col3" >46172.4553</td>
#       <td id="T_b6076_row0_col4" class="data row0 col4" >0.8388</td>
#       <td id="T_b6076_row0_col5" class="data row0 col5" >0.2318</td>
#       <td id="T_b6076_row0_col6" class="data row0 col6" >0.1781</td>
#     </tr>
#   </tbody>
# </table>
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19121 -122.639999  38.240002                40.0       1974.0           410.0
# 20019 -119.050003  36.090000                 9.0       3297.0           568.0
# 15104 -116.980003  32.849998                12.0       3570.0           713.0
# 3720  -118.419998  34.200001                27.0       3201.0           970.0
# 8938  -118.470001  34.009998                41.0       2704.0           557.0
#
#        population  households  median_income ocean_proximity  \
# 19121      1039.0       398.0         3.7917       <1H OCEAN
# 20019      1749.0       568.0         4.0217          INLAND
# 15104      3321.0       666.0         4.0882       <1H OCEAN
# 3720       3403.0       948.0         2.2377       <1H OCEAN
# 8938       1047.0       478.0         4.4211       <1H OCEAN
#
#        median_house_value  prediction_label
# 19121            151600.0     198882.814187
# 20019             99200.0     101132.884212
# 15104            134500.0     158276.279342
# 3720             231700.0     187507.999339
# 8938             462900.0     453448.462461

# %%
save_model(best, 'california_housing_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['longitude', 'latitude',
#                                               'housing_median_age',
#                                               'total_rooms', 'total_bedrooms',
#                                               'population', 'households',
#                                               'median_income'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['ocean_proximity'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['ocean_proximity'],
#                                      transformer=OneHotEncoder(cols=['ocean_proximity'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('trained_model', LGBMRegressor(n_jobs=-1, random_state=123))]),
#  'california_housing_model.pkl')
