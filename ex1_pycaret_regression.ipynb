# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafak22/python/blob/main/ex1_pycaret_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # M4.Ex1: Housing Prices Model (PyCaret)

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M6/exercises/ex1_pycaret_regression.ipynb)

# %% [markdown]
# ## Exercise
#
# Your task is to follow the steps outlined here, and apply them on the **California Housing Dataset** below:
#
# - [**🚀 Regression**](https://pycaret.gitbook.io/docs/get-started/quickstart#regression)
#     - Setup
#     - Compare Models
#     - Analyze Model
#     - Predictions
#     - Save the model

# %% [markdown]
# ## California Housing Prices Dataset
#
#
# Find and download the dataset from Kaggle at [California Housing Dataset](https://www.kaggle.com/datasets/dhirajnirne/california-housing-data).
#
# According to [keras.io](https://keras.io/api/datasets/california_housing/):
#
# > This dataset was obtained from the StatLib repository.
# >
# > It's a continuous regression dataset with 20,640 samples with 8 features each.
# >
# > The target variable is a scalar: the median house value for California districts, in dollars.
# >
# > The 8 input features are the following:
# >
# > - MedInc: median income in block group
# > - HouseAge: median house age in block group
# > - AveRooms: average number of rooms per household
# > - AveBedrms: average number of bedrooms per household
# > - Population: block group population
# > - AveOccup: average number of household members
# > - Latitude: block group latitude
# > - Longitude: block group longitude
# >
# > This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
# >
# > A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surprisingly large values for block groups with few households and many empty houses, such as vacation resorts.

# %% [markdown]
# ### Load the data

# %% [markdown]
# **Task**: Your model should learn from this data and be able to predict the median housing price (`median_house_value`) in any district, given all the other metrics.
#
# Please read the above dataset description to understand what the features mean.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

data = fetch_california_housing(as_frame=True)
df = data.frame
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
clean_content = '''import sys
from pycaret.utils._show_versions import show_versions

version_ = "3.3.2"

__version__ = version_

__all__ = ["show_versions", "__version__"]

if sys.version_info < (3, 9):
    raise RuntimeError(
        sys.version_info,
        "Please UPGRADE your Python version.",
    )
'''

with open('/usr/local/lib/python3.12/dist-packages/pycaret/__init__.py', 'w') as f:
    f.write(clean_content)

print("Fixed!")
# Out:
# Fixed!

# %%
from pycaret.regression import *
s = setup(df, target='MedHouseVal', session_id=123)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7041/2879140009.py in <cell line: 0>()
#       1 from pycaret.regression import *
# ----> 2 s = setup(df, target='MedHouseVal', session_id=123)
#
# /usr/local/lib/python3.12/dist-packages/pycaret/regression/functional.py in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     591     exp = _EXPERIMENT_CLASS()
#     592     set_current_experiment(exp)
# --> 593     return exp.setup(
#     594         data=data,
#     595         data_func=data_func,
#
# /usr/local/lib/python3.12/dist-packages/pycaret/regression/oop.py in setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     740         )
#     741
# --> 742         self._set_exp_model_engines(
#     743             container_default_engines=get_container_default_engines(),
#     744             engine=engine,
#
# /usr/local/lib/python3.12/dist-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_exp_model_engines(self, container_default_engines, engine)
#    2847             # If provided by user, then use that, else get from the defaults
#    2848             eng = engine.get(key, container_default_engines.get(key))
# -> 2849             self._set_engine(estimator=key, engine=eng, severity="error")
#    2850
#    2851         return self
#
# /usr/local/lib/python3.12/dist-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_engine(self, estimator, engine, severity)
#    2813
#    2814         # Need to do this, else internal class variables are not reset with new engine.
# -> 2815         self._set_all_models()
#    2816
#    2817     def _set_exp_model_engines(
#
# /usr/local/lib/python3.12/dist-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py in _set_all_models(self)
#    2703             The experiment object to allow chaining of methods
#    2704         """
# -> 2705         self._all_models, self._all_models_internal = self._get_models()
#    2706         return self
#    2707
#
# /usr/local/lib/python3.12/dist-packages/pycaret/regression/oop.py in _get_models(self, raise_errors)
#      60         all_models = {
#      61             k: v
# ---> 62             for k, v in get_all_model_containers(
#      63                 self, raise_errors=raise_errors
#      64             ).items()
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/models/regression.py in get_all_model_containers(experiment, raise_errors)
#    1994     experiment: Any, raise_errors: bool = True
#    1995 ) -> Dict[str, RegressorContainer]:
# -> 1996     return pycaret.containers.base_container.get_all_containers(
#    1997         globals(), experiment, RegressorContainer, raise_errors
#    1998     )
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/base_container.py in get_all_containers(container_globals, experiment, type_var, raise_errors)
#     117             if hasattr(obj, "active") and not obj.active:
#     118                 continue
# --> 119             instance = obj(experiment)
#     120             if instance.active:
#     121                 model_containers.append(instance)
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/models/regression.py in __init__(self, experiment)
#     261         leftover_parameters_to_categorical_distributions(tune_grid, tune_distributions)
#     262
# --> 263         super().__init__(
#     264             id=id,
#     265             name="Linear Regression",
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/models/regression.py in __init__(self, id, name, class_def, is_turbo, eq_function, args, is_special, tune_grid, tune_distribution, tune_args, shap, is_gpu_enabled, tunable)
#     158             tune_args = {}
#     159
# --> 160         super().__init__(
#     161             id=id,
#     162             name=name,
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/models/base_model.py in __init__(self, id, name, class_def, eq_function, args, is_special)
#      60         is_special: bool = False,
#      61     ) -> None:
# ---> 62         super().__init__(id=id, name=name, class_def=class_def, args=args)
#      63         self.reference = self.get_class_name()
#      64         if not eq_function:
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/base_container.py in __init__(self, id, name, class_def, args)
#      57         self.name = name
#      58         self.class_def = class_def
# ---> 59         self.reference = self.get_class_name()
#      60         self.args = args
#      61         self.active = True
#
# /usr/local/lib/python3.12/dist-packages/pycaret/containers/base_container.py in get_class_name(self)
#      62
#      63     def get_class_name(self):
# ---> 64         return pycaret.utils.generic.get_class_name(self.class_def)
#      65
#      66     def get_package_name(self):
#
# AttributeError: module 'pycaret' has no attribute 'utils'
