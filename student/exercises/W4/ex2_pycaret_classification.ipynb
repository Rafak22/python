# %% [markdown]
# # M4.Ex2: Penguins Classification (PyCaret)

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M6/exercises/ex2_pycaret_classification.ipynb)

# %% [markdown]
# ## Exercise
#
# Your task is to follow the steps outlined here, and apply them on the **Palmer Penguins Dataset** below:
#
# - [**🚀 Classification**](https://pycaret.gitbook.io/docs/get-started/quickstart#classification)
#     - Setup
#     - Compare Models
#     - Analyze Model
#     - Predictions
#     - Save the model

# %% [markdown]
# ## Palmer Penguins Dataset
#
# The goal of palmer penguins is to provide a great dataset for data exploration & visualization, as an alternative to iris.
#
# The data contains 344 penguins. There are 3 different species of penguins in this dataset, collected from 3 islands in the Palmer Archipelago, Antarctica.
#
# - Features: `4` numerical, `2` categorical
# - Target: `species` (Categorical / 3 classes)
# - Size: `344` samples
# - Source: [Palmer Penguins](https://allisonhorst.github.io/palmerpenguins/)

# %% [markdown]
# ### Load the data

# %%
import seaborn as sns

penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ## Experiments
#
# 1. **First experiment**:
#     - X = Flipper Length (numerical) & Bill Length (numerical)
#     - y = Species (categorical)
# 2. **Second experiment**:
#     - X = Weights (numerical) & Species (categorical)
#     - y = Sex (categroical)
# 3. **Third experiment**:
#     - X = `island`, `bill_length_mm`, `bill_depth_mm`, `flipper_length_mm`, `body_mass_g`
#     - y = Sex and Species (multi-label classification)

# %%
# !pip install git+https://github.com/pycaret/pycaret.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip install numpy==1.26.4 -q --force-reinstall
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.4.2 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# spopt 0.7.0 requires scipy>=1.12.0, but you have scipy 1.11.4 which is incompatible.
# pointpats 2.5.5 requires matplotlib>=3.9, but you have matplotlib 3.7.5 which is incompatible.
# pointpats 2.5.5 requires pandas>=2.2, but you have pandas 2.1.4 which is incompatible.
# pointpats 2.5.5 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# inequality 1.1.2 requires matplotlib>=3.8, but you have matplotlib 3.7.5 which is incompatible.
# inequality 1.1.2 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires pandas>=2.2, but you have pandas 2.1.4 which is incompatible.
# tobler 0.14.0 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# esda 2.9.0 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# arviz 0.22.0 requires matplotlib>=3.8, but you have matplotlib 3.7.5 which is incompatible.
# xarray 2025.12.0 requires pandas>=2.2, but you have pandas 2.1.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.4.2 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# libpysal 4.14.1 requires scipy>=1.12.0, but you have scipy 1.11.4 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.11.4 which is incompatible.
# mapclassify 2.10.0 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.

# %%
#experiment1
from pycaret.classification import *

df1 = penguins[['flipper_length_mm', 'bill_length_mm', 'species']].dropna()

s1 = setup(df1, target='species', session_id=123)
best1 = compare_models()
evaluate_model(best1)
predictions1 = predict_model(best1)
save_model(best1, 'exp1_species_model')
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7e1d7717fc40>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1187, in _make_controller_from_path
#     lib_controller = controller_class(
#                      ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: dlopen() error
# <style type="text/css">
# #T_e6ff2_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e6ff2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6ff2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e6ff2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6ff2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6ff2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e6ff2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6ff2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e6ff2_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6ff2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e6ff2_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6ff2_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_e6ff2_row3_col1" class="data row3 col1" >Adelie: 0, Chinstrap: 1, Gentoo: 2</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6ff2_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e6ff2_row4_col1" class="data row4 col1" >(342, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e6ff2_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e6ff2_row5_col1" class="data row5 col1" >(342, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e6ff2_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e6ff2_row6_col1" class="data row6 col1" >(239, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e6ff2_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e6ff2_row7_col1" class="data row7 col1" >(103, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e6ff2_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e6ff2_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e6ff2_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e6ff2_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e6ff2_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e6ff2_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e6ff2_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e6ff2_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e6ff2_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e6ff2_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e6ff2_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_e6ff2_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e6ff2_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_e6ff2_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e6ff2_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_e6ff2_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e6ff2_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_e6ff2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e6ff2_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_e6ff2_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e6ff2_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_e6ff2_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e6ff2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e6ff2_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_e6ff2_row19_col1" class="data row19 col1" >89ac</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dec93 th {
#   text-align: left;
# }
# #T_dec93_row0_col0, #T_dec93_row0_col2, #T_dec93_row1_col0, #T_dec93_row1_col1, #T_dec93_row1_col2, #T_dec93_row1_col3, #T_dec93_row1_col4, #T_dec93_row1_col5, #T_dec93_row1_col6, #T_dec93_row1_col7, #T_dec93_row2_col0, #T_dec93_row2_col1, #T_dec93_row2_col2, #T_dec93_row2_col3, #T_dec93_row2_col4, #T_dec93_row2_col5, #T_dec93_row2_col6, #T_dec93_row2_col7, #T_dec93_row3_col0, #T_dec93_row3_col1, #T_dec93_row3_col3, #T_dec93_row3_col4, #T_dec93_row3_col5, #T_dec93_row3_col6, #T_dec93_row3_col7, #T_dec93_row4_col0, #T_dec93_row4_col1, #T_dec93_row4_col2, #T_dec93_row4_col3, #T_dec93_row4_col4, #T_dec93_row4_col5, #T_dec93_row4_col6, #T_dec93_row4_col7, #T_dec93_row5_col0, #T_dec93_row5_col1, #T_dec93_row5_col2, #T_dec93_row5_col3, #T_dec93_row5_col4, #T_dec93_row5_col5, #T_dec93_row5_col6, #T_dec93_row5_col7, #T_dec93_row6_col0, #T_dec93_row6_col1, #T_dec93_row6_col2, #T_dec93_row6_col3, #T_dec93_row6_col4, #T_dec93_row6_col5, #T_dec93_row6_col6, #T_dec93_row6_col7, #T_dec93_row7_col0, #T_dec93_row7_col1, #T_dec93_row7_col2, #T_dec93_row7_col3, #T_dec93_row7_col4, #T_dec93_row7_col5, #T_dec93_row7_col6, #T_dec93_row7_col7, #T_dec93_row8_col0, #T_dec93_row8_col1, #T_dec93_row8_col2, #T_dec93_row8_col3, #T_dec93_row8_col4, #T_dec93_row8_col5, #T_dec93_row8_col6, #T_dec93_row8_col7, #T_dec93_row9_col0, #T_dec93_row9_col1, #T_dec93_row9_col2, #T_dec93_row9_col3, #T_dec93_row9_col4, #T_dec93_row9_col5, #T_dec93_row9_col6, #T_dec93_row9_col7, #T_dec93_row10_col0, #T_dec93_row10_col1, #T_dec93_row10_col2, #T_dec93_row10_col3, #T_dec93_row10_col4, #T_dec93_row10_col5, #T_dec93_row10_col6, #T_dec93_row10_col7, #T_dec93_row11_col0, #T_dec93_row11_col1, #T_dec93_row11_col2, #T_dec93_row11_col3, #T_dec93_row11_col4, #T_dec93_row11_col5, #T_dec93_row11_col6, #T_dec93_row11_col7, #T_dec93_row12_col0, #T_dec93_row12_col1, #T_dec93_row12_col2, #T_dec93_row12_col3, #T_dec93_row12_col4, #T_dec93_row12_col5, #T_dec93_row12_col6, #T_dec93_row12_col7, #T_dec93_row13_col0, #T_dec93_row13_col1, #T_dec93_row13_col2, #T_dec93_row13_col3, #T_dec93_row13_col4, #T_dec93_row13_col5, #T_dec93_row13_col6, #T_dec93_row13_col7, #T_dec93_row14_col0, #T_dec93_row14_col1, #T_dec93_row14_col2, #T_dec93_row14_col3, #T_dec93_row14_col4, #T_dec93_row14_col5, #T_dec93_row14_col6, #T_dec93_row14_col7 {
#   text-align: left;
# }
# #T_dec93_row0_col1, #T_dec93_row0_col3, #T_dec93_row0_col4, #T_dec93_row0_col5, #T_dec93_row0_col6, #T_dec93_row0_col7, #T_dec93_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dec93_row0_col8, #T_dec93_row1_col8, #T_dec93_row3_col8, #T_dec93_row4_col8, #T_dec93_row5_col8, #T_dec93_row6_col8, #T_dec93_row7_col8, #T_dec93_row8_col8, #T_dec93_row9_col8, #T_dec93_row10_col8, #T_dec93_row11_col8, #T_dec93_row12_col8, #T_dec93_row13_col8, #T_dec93_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dec93_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dec93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dec93_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dec93_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_dec93_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_dec93_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_dec93_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_dec93_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_dec93_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_dec93_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_dec93_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dec93_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_dec93_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_dec93_row0_col1" class="data row0 col1" >0.9453</td>
#       <td id="T_dec93_row0_col2" class="data row0 col2" >0.9774</td>
#       <td id="T_dec93_row0_col3" class="data row0 col3" >0.9453</td>
#       <td id="T_dec93_row0_col4" class="data row0 col4" >0.9519</td>
#       <td id="T_dec93_row0_col5" class="data row0 col5" >0.9431</td>
#       <td id="T_dec93_row0_col6" class="data row0 col6" >0.9137</td>
#       <td id="T_dec93_row0_col7" class="data row0 col7" >0.9180</td>
#       <td id="T_dec93_row0_col8" class="data row0 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_dec93_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_dec93_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_dec93_row1_col1" class="data row1 col1" >0.9409</td>
#       <td id="T_dec93_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_dec93_row1_col3" class="data row1 col3" >0.9409</td>
#       <td id="T_dec93_row1_col4" class="data row1 col4" >0.9431</td>
#       <td id="T_dec93_row1_col5" class="data row1 col5" >0.9392</td>
#       <td id="T_dec93_row1_col6" class="data row1 col6" >0.9067</td>
#       <td id="T_dec93_row1_col7" class="data row1 col7" >0.9089</td>
#       <td id="T_dec93_row1_col8" class="data row1 col8" >0.5050</td>
#     </tr>
#     <tr>
#       <th id="T_dec93_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_dec93_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_dec93_row2_col1" class="data row2 col1" >0.9409</td>
#       <td id="T_dec93_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_dec93_row2_col3" class="data row2 col3" >0.9409</td>
#       <td id="T_dec93_row2_col4" class="data row2 col4" >0.9431</td>
#       <td id="T_dec93_row2_col5" class="data row2 col5" >0.9392</td>
#       <td id="T_dec93_row2_col6" class="data row2 col6" >0.9067</td>
#       <td id="T_dec93_row2_col7" class="data row2 col7" >0.9089</td>
#       <td id="T_dec93_row2_col8" class="data row2 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_dec93_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_dec93_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_dec93_row3_col1" class="data row3 col1" >0.9409</td>
#       <td id="T_dec93_row3_col2" class="data row3 col2" >0.9920</td>
#       <td id="T_dec93_row3_col3" class="data row3 col3" >0.9409</td>
#       <td id="T_dec93_row3_col4" class="data row3 col4" >0.9488</td>
#       <td id="T_dec93_row3_col5" class="data row3 col5" >0.9407</td>
#       <td id="T_dec93_row3_col6" class="data row3 col6" >0.9076</td>
#       <td id="T_dec93_row3_col7" class="data row3 col7" >0.9111</td>
#       <td id="T_dec93_row3_col8" class="data row3 col8" >0.1320</td>
#     </tr>
#     <tr>
#       <th id="T_dec93_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_dec93_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_dec93_row4_col1" class="data row4 col1" >0.9409</td>
#       <td id="T_dec93_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_dec93_row4_col3" class="data row4 col3" >0.9409</td>
#       <td id="T_dec93_row4_col4" class="data row4 col4" >0.9431</td>
#       <td id="T_dec93_row4_col5" class="data row4 col5" >0.9394</td>
#       <td id="T_dec93_row4_col6" class="data row4 col6" >0.9066</td>
#       <td id="T_dec93_row4_col7" class="data row4 col7" >0.9088</td>
#       <td id="T_dec93_row4_col8" class="data row4 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_dec93_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_dec93_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_dec93_row5_col1" class="data row5 col1" >0.9409</td>
#       <td id="T_dec93_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_dec93_row5_col3" class="data row5 col3" >0.9409</td>
#       <td id="T_dec93_row5_col4" class="data row5 col4" >0.9431</td>
#       <td id
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_fd1f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd1f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd1f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fd1f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fd1f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fd1f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fd1f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fd1f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fd1f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd1f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd1f3_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_fd1f3_row0_col1" class="data row0 col1" >0.9806</td>
#       <td id="T_fd1f3_row0_col2" class="data row0 col2" >0.9908</td>
#       <td id="T_fd1f3_row0_col3" class="data row0 col3" >0.9806</td>
#       <td id="T_fd1f3_row0_col4" class="data row0 col4" >0.9808</td>
#       <td id="T_fd1f3_row0_col5" class="data row0 col5" >0.9805</td>
#       <td id="T_fd1f3_row0_col6" class="data row0 col6" >0.9695</td>
#       <td id="T_fd1f3_row0_col7" class="data row0 col7" >0.9697</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['flipper_length_mm',
#                                               'bill_length_mm'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                miss...
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='minkowski', metric_params=None,
#                                        n_jobs=-1, n_neighbors=5, p=2,
#                                        weights='uniform'))],
#           verbose=False),
#  'exp1_species_model.pkl')

# %%
#experiment2
df2 = penguins[['body_mass_g', 'species', 'sex']].dropna()

s2 = setup(df2, target='sex', session_id=123)
best2 = compare_models()
evaluate_model(best2)
predictions2 = predict_model(best2)
save_model(best2, 'exp2_sex_model')
# Out:
# <style type="text/css">
# #T_aeb9f_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aeb9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeb9f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aeb9f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeb9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeb9f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aeb9f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aeb9f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aeb9f_row1_col1" class="data row1 col1" >sex</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aeb9f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_aeb9f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aeb9f_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_aeb9f_row3_col1" class="data row3 col1" >Female: 0, Male: 1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aeb9f_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_aeb9f_row4_col1" class="data row4 col1" >(333, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aeb9f_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_aeb9f_row5_col1" class="data row5 col1" >(333, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aeb9f_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_aeb9f_row6_col1" class="data row6 col1" >(233, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aeb9f_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_aeb9f_row7_col1" class="data row7 col1" >(100, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aeb9f_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_aeb9f_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aeb9f_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_aeb9f_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aeb9f_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_aeb9f_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aeb9f_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_aeb9f_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aeb9f_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_aeb9f_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aeb9f_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_aeb9f_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aeb9f_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_aeb9f_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aeb9f_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_aeb9f_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aeb9f_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_aeb9f_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aeb9f_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_aeb9f_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aeb9f_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_aeb9f_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aeb9f_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_aeb9f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_aeb9f_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_aeb9f_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_aeb9f_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_aeb9f_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_aeb9f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_aeb9f_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_aeb9f_row22_col1" class="data row22 col1" >4a9a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f113f th {
#   text-align: left;
# }
# #T_f113f_row0_col0, #T_f113f_row0_col2, #T_f113f_row1_col0, #T_f113f_row1_col1, #T_f113f_row1_col3, #T_f113f_row1_col4, #T_f113f_row1_col5, #T_f113f_row1_col6, #T_f113f_row1_col7, #T_f113f_row2_col0, #T_f113f_row2_col1, #T_f113f_row2_col2, #T_f113f_row2_col3, #T_f113f_row2_col4, #T_f113f_row2_col5, #T_f113f_row2_col6, #T_f113f_row2_col7, #T_f113f_row3_col0, #T_f113f_row3_col1, #T_f113f_row3_col2, #T_f113f_row3_col3, #T_f113f_row3_col4, #T_f113f_row3_col5, #T_f113f_row3_col6, #T_f113f_row3_col7, #T_f113f_row4_col0, #T_f113f_row4_col1, #T_f113f_row4_col2, #T_f113f_row4_col3, #T_f113f_row4_col4, #T_f113f_row4_col5, #T_f113f_row4_col6, #T_f113f_row4_col7, #T_f113f_row5_col0, #T_f113f_row5_col1, #T_f113f_row5_col2, #T_f113f_row5_col3, #T_f113f_row5_col4, #T_f113f_row5_col5, #T_f113f_row5_col6, #T_f113f_row5_col7, #T_f113f_row6_col0, #T_f113f_row6_col1, #T_f113f_row6_col2, #T_f113f_row6_col3, #T_f113f_row6_col4, #T_f113f_row6_col5, #T_f113f_row6_col6, #T_f113f_row6_col7, #T_f113f_row7_col0, #T_f113f_row7_col1, #T_f113f_row7_col2, #T_f113f_row7_col3, #T_f113f_row7_col4, #T_f113f_row7_col5, #T_f113f_row7_col6, #T_f113f_row7_col7, #T_f113f_row8_col0, #T_f113f_row8_col1, #T_f113f_row8_col2, #T_f113f_row8_col3, #T_f113f_row8_col4, #T_f113f_row8_col5, #T_f113f_row8_col6, #T_f113f_row8_col7, #T_f113f_row9_col0, #T_f113f_row9_col1, #T_f113f_row9_col2, #T_f113f_row9_col3, #T_f113f_row9_col4, #T_f113f_row9_col5, #T_f113f_row9_col6, #T_f113f_row9_col7, #T_f113f_row10_col0, #T_f113f_row10_col1, #T_f113f_row10_col2, #T_f113f_row10_col3, #T_f113f_row10_col4, #T_f113f_row10_col5, #T_f113f_row10_col6, #T_f113f_row10_col7, #T_f113f_row11_col0, #T_f113f_row11_col1, #T_f113f_row11_col2, #T_f113f_row11_col3, #T_f113f_row11_col4, #T_f113f_row11_col5, #T_f113f_row11_col6, #T_f113f_row11_col7, #T_f113f_row12_col0, #T_f113f_row12_col1, #T_f113f_row12_col2, #T_f113f_row12_col3, #T_f113f_row12_col4, #T_f113f_row12_col5, #T_f113f_row12_col6, #T_f113f_row12_col7, #T_f113f_row13_col0, #T_f113f_row13_col1, #T_f113f_row13_col2, #T_f113f_row13_col3, #T_f113f_row13_col4, #T_f113f_row13_col5, #T_f113f_row13_col6, #T_f113f_row13_col7, #T_f113f_row14_col0, #T_f113f_row14_col1, #T_f113f_row14_col2, #T_f113f_row14_col3, #T_f113f_row14_col4, #T_f113f_row14_col5, #T_f113f_row14_col6, #T_f113f_row14_col7 {
#   text-align: left;
# }
# #T_f113f_row0_col1, #T_f113f_row0_col3, #T_f113f_row0_col4, #T_f113f_row0_col5, #T_f113f_row0_col6, #T_f113f_row0_col7, #T_f113f_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f113f_row0_col8, #T_f113f_row1_col8, #T_f113f_row3_col8, #T_f113f_row4_col8, #T_f113f_row5_col8, #T_f113f_row6_col8, #T_f113f_row7_col8, #T_f113f_row8_col8, #T_f113f_row9_col8, #T_f113f_row10_col8, #T_f113f_row11_col8, #T_f113f_row12_col8, #T_f113f_row13_col8, #T_f113f_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f113f_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f113f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f113f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f113f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f113f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f113f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f113f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f113f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f113f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f113f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f113f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f113f_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_f113f_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_f113f_row0_col1" class="data row0 col1" >0.8627</td>
#       <td id="T_f113f_row0_col2" class="data row0 col2" >0.9139</td>
#       <td id="T_f113f_row0_col3" class="data row0 col3" >0.8627</td>
#       <td id="T_f113f_row0_col4" class="data row0 col4" >0.8683</td>
#       <td id="T_f113f_row0_col5" class="data row0 col5" >0.8617</td>
#       <td id="T_f113f_row0_col6" class="data row0 col6" >0.7249</td>
#       <td id="T_f113f_row0_col7" class="data row0 col7" >0.7305</td>
#       <td id="T_f113f_row0_col8" class="data row0 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_f113f_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_f113f_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_f113f_row1_col1" class="data row1 col1" >0.8591</td>
#       <td id="T_f113f_row1_col2" class="data row1 col2" >0.9459</td>
#       <td id="T_f113f_row1_col3" class="data row1 col3" >0.8591</td>
#       <td id="T_f113f_row1_col4" class="data row1 col4" >0.8623</td>
#       <td id="T_f113f_row1_col5" class="data row1 col5" >0.8586</td>
#       <td id="T_f113f_row1_col6" class="data row1 col6" >0.7176</td>
#       <td id="T_f113f_row1_col7" class="data row1 col7" >0.7209</td>
#       <td id="T_f113f_row1_col8" class="data row1 col8" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_f113f_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_f113f_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f113f_row2_col1" class="data row2 col1" >0.8551</td>
#       <td id="T_f113f_row2_col2" class="data row2 col2" >0.9423</td>
#       <td id="T_f113f_row2_col3" class="data row2 col3" >0.8551</td>
#       <td id="T_f113f_row2_col4" class="data row2 col4" >0.8594</td>
#       <td id="T_f113f_row2_col5" class="data row2 col5" >0.8544</td>
#       <td id="T_f113f_row2_col6" class="data row2 col6" >0.7097</td>
#       <td id="T_f113f_row2_col7" class="data row2 col7" >0.7141</td>
#       <td id="T_f113f_row2_col8" class="data row2 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_f113f_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_f113f_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_f113f_row3_col1" class="data row3 col1" >0.8543</td>
#       <td id="T_f113f_row3_col2" class="data row3 col2" >0.9344</td>
#       <td id="T_f113f_row3_col3" class="data row3 col3" >0.8543</td>
#       <td id="T_f113f_row3_col4" class="data row3 col4" >0.8587</td>
#       <td id="T_f113f_row3_col5" class="data row3 col5" >0.8539</td>
#       <td id="T_f113f_row3_col6" class="data row3 col6" >0.7083</td>
#       <td id="T_f113f_row3_col7" class="data row3 col7" >0.7127</td>
#       <td id="T_f113f_row3_col8" class="data row3 col8" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_f113f_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_f113f_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_f113f_row4_col1" class="data row4 col1" >0.8373</td>
#       <td id="T_f113f_row4_col2" class="data row4 col2" >0.8657</td>
#       <td id="T_f113f_row4_col3" class="data row4 col3" >0.8373</td>
#       <td id="T_f113f_row4_col4" class="data row4 col4" >0.8489</td>
#       <td id="T_f113f_row4_col5" class="data row4 col5" >0.8354</td>
#       <td id="T_f113f_row4_col6" class="data row4 col6" >0.6737</td>
#       <td id="T_f113f_row4_col7" class="data row4 col7" >0.6852</td>
#       <td id="T_f113f_row4_col8" class="data row4 col8" >0.1460</td>
#     </tr>
#     <tr>
#       <th id="T_f113f_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_f113f_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_f113f_row5_col1" class="data row5 col1" >0.8371</td>
#       <td id="T_f113f_row5_col2" class="data row5 col2" >0.8546</td>
#       <td id="T_f113f_row5_col3" class="data row5 col3" >0.8371</td>
#       <td id="T_f113f_row5_col4" class="data row5 col4" >0.8467</td>
#       <td id="T_f113f_ro
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_4db1e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4db1e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4db1e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4db1e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4db1e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4db1e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4db1e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4db1e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4db1e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4db1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4db1e_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_4db1e_row0_col1" class="data row0 col1" >0.8300</td>
#       <td id="T_4db1e_row0_col2" class="data row0 col2" >0.9020</td>
#       <td id="T_4db1e_row0_col3" class="data row0 col3" >0.8300</td>
#       <td id="T_4db1e_row0_col4" class="data row0 col4" >0.8301</td>
#       <td id="T_4db1e_row0_col5" class="data row0 col5" >0.8300</td>
#       <td id="T_4db1e_row0_col6" class="data row0 col6" >0.6600</td>
#       <td id="T_4db1e_row0_col7" class="data row0 col7" >0.6601</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=['body_mass_g'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy...
#                   TransformerWrapper(exclude=None, include=['species'],
#                                      transformer=OneHotEncoder(cols=['species'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R', estimator=None,
#                                      learning_rate=1.0, n_estimators=50,
#                                      random_state=123))],
#           verbose=False),
#  'exp2_sex_model.pkl')

# %%
#experiment3
df3 = penguins[['island', 'bill_length_mm', 'bill_depth_mm',
                'flipper_length_mm', 'body_mass_g', 'species']].dropna()

s3 = setup(df3, target='species', session_id=123)
best3 = compare_models()
evaluate_model(best3)
predictions3 = predict_model(best3)
save_model(best3, 'exp3_multifeature_model')
# Out:
# <style type="text/css">
# #T_95b3d_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_95b3d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95b3d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_95b3d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95b3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95b3d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_95b3d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95b3d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_95b3d_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_95b3d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_95b3d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_95b3d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_95b3d_row3_col1" class="data row3 col1" >Adelie: 0, Chinstrap: 1, Gentoo: 2</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_95b3d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_95b3d_row4_col1" class="data row4 col1" >(342, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_95b3d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_95b3d_row5_col1" class="data row5 col1" >(342, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_95b3d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_95b3d_row6_col1" class="data row6 col1" >(239, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_95b3d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_95b3d_row7_col1" class="data row7 col1" >(103, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_95b3d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_95b3d_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_95b3d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_95b3d_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_95b3d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_95b3d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_95b3d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_95b3d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_95b3d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_95b3d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_95b3d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_95b3d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_95b3d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_95b3d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_95b3d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_95b3d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_95b3d_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_95b3d_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_95b3d_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_95b3d_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_95b3d_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_95b3d_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_95b3d_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_95b3d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_95b3d_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_95b3d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_95b3d_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_95b3d_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_95b3d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_95b3d_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_95b3d_row22_col1" class="data row22 col1" >b410</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3f70d th {
#   text-align: left;
# }
# #T_3f70d_row0_col0, #T_3f70d_row0_col2, #T_3f70d_row1_col0, #T_3f70d_row1_col1, #T_3f70d_row1_col2, #T_3f70d_row1_col3, #T_3f70d_row1_col4, #T_3f70d_row1_col5, #T_3f70d_row1_col6, #T_3f70d_row1_col7, #T_3f70d_row2_col0, #T_3f70d_row2_col1, #T_3f70d_row2_col2, #T_3f70d_row2_col3, #T_3f70d_row2_col4, #T_3f70d_row2_col5, #T_3f70d_row2_col6, #T_3f70d_row2_col7, #T_3f70d_row3_col0, #T_3f70d_row3_col1, #T_3f70d_row3_col2, #T_3f70d_row3_col3, #T_3f70d_row3_col4, #T_3f70d_row3_col5, #T_3f70d_row3_col6, #T_3f70d_row3_col7, #T_3f70d_row4_col0, #T_3f70d_row4_col1, #T_3f70d_row4_col2, #T_3f70d_row4_col3, #T_3f70d_row4_col4, #T_3f70d_row4_col5, #T_3f70d_row4_col6, #T_3f70d_row4_col7, #T_3f70d_row5_col0, #T_3f70d_row5_col1, #T_3f70d_row5_col3, #T_3f70d_row5_col4, #T_3f70d_row5_col5, #T_3f70d_row5_col6, #T_3f70d_row5_col7, #T_3f70d_row6_col0, #T_3f70d_row6_col1, #T_3f70d_row6_col3, #T_3f70d_row6_col4, #T_3f70d_row6_col5, #T_3f70d_row6_col6, #T_3f70d_row6_col7, #T_3f70d_row7_col0, #T_3f70d_row7_col1, #T_3f70d_row7_col2, #T_3f70d_row7_col3, #T_3f70d_row7_col4, #T_3f70d_row7_col5, #T_3f70d_row7_col6, #T_3f70d_row7_col7, #T_3f70d_row8_col0, #T_3f70d_row8_col1, #T_3f70d_row8_col2, #T_3f70d_row8_col3, #T_3f70d_row8_col4, #T_3f70d_row8_col5, #T_3f70d_row8_col6, #T_3f70d_row8_col7, #T_3f70d_row9_col0, #T_3f70d_row9_col1, #T_3f70d_row9_col2, #T_3f70d_row9_col3, #T_3f70d_row9_col4, #T_3f70d_row9_col5, #T_3f70d_row9_col6, #T_3f70d_row9_col7, #T_3f70d_row10_col0, #T_3f70d_row10_col1, #T_3f70d_row10_col2, #T_3f70d_row10_col3, #T_3f70d_row10_col4, #T_3f70d_row10_col5, #T_3f70d_row10_col6, #T_3f70d_row10_col7, #T_3f70d_row11_col0, #T_3f70d_row11_col1, #T_3f70d_row11_col2, #T_3f70d_row11_col3, #T_3f70d_row11_col4, #T_3f70d_row11_col5, #T_3f70d_row11_col6, #T_3f70d_row11_col7, #T_3f70d_row12_col0, #T_3f70d_row12_col1, #T_3f70d_row12_col2, #T_3f70d_row12_col3, #T_3f70d_row12_col4, #T_3f70d_row12_col5, #T_3f70d_row12_col6, #T_3f70d_row12_col7, #T_3f70d_row13_col0, #T_3f70d_row13_col1, #T_3f70d_row13_col2, #T_3f70d_row13_col3, #T_3f70d_row13_col4, #T_3f70d_row13_col5, #T_3f70d_row13_col6, #T_3f70d_row13_col7, #T_3f70d_row14_col0, #T_3f70d_row14_col1, #T_3f70d_row14_col2, #T_3f70d_row14_col3, #T_3f70d_row14_col4, #T_3f70d_row14_col5, #T_3f70d_row14_col6, #T_3f70d_row14_col7 {
#   text-align: left;
# }
# #T_3f70d_row0_col1, #T_3f70d_row0_col3, #T_3f70d_row0_col4, #T_3f70d_row0_col5, #T_3f70d_row0_col6, #T_3f70d_row0_col7, #T_3f70d_row5_col2, #T_3f70d_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3f70d_row0_col8, #T_3f70d_row1_col8, #T_3f70d_row2_col8, #T_3f70d_row3_col8, #T_3f70d_row4_col8, #T_3f70d_row5_col8, #T_3f70d_row6_col8, #T_3f70d_row7_col8, #T_3f70d_row9_col8, #T_3f70d_row10_col8, #T_3f70d_row11_col8, #T_3f70d_row12_col8, #T_3f70d_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3f70d_row8_col8, #T_3f70d_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3f70d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f70d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3f70d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3f70d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3f70d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3f70d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3f70d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3f70d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3f70d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3f70d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f70d_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_3f70d_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3f70d_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_3f70d_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_3f70d_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_3f70d_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_3f70d_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_3f70d_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_3f70d_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_3f70d_row0_col8" class="data row0 col8" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_3f70d_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_3f70d_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_3f70d_row1_col1" class="data row1 col1" >0.9958</td>
#       <td id="T_3f70d_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_3f70d_row1_col3" class="data row1 col3" >0.9958</td>
#       <td id="T_3f70d_row1_col4" class="data row1 col4" >0.9962</td>
#       <td id="T_3f70d_row1_col5" class="data row1 col5" >0.9957</td>
#       <td id="T_3f70d_row1_col6" class="data row1 col6" >0.9934</td>
#       <td id="T_3f70d_row1_col7" class="data row1 col7" >0.9937</td>
#       <td id="T_3f70d_row1_col8" class="data row1 col8" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_3f70d_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_3f70d_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_3f70d_row2_col1" class="data row2 col1" >0.9917</td>
#       <td id="T_3f70d_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_3f70d_row2_col3" class="data row2 col3" >0.9917</td>
#       <td id="T_3f70d_row2_col4" class="data row2 col4" >0.9928</td>
#       <td id="T_3f70d_row2_col5" class="data row2 col5" >0.9917</td>
#       <td id="T_3f70d_row2_col6" class="data row2 col6" >0.9868</td>
#       <td id="T_3f70d_row2_col7" class="data row2 col7" >0.9873</td>
#       <td id="T_3f70d_row2_col8" class="data row2 col8" >0.1620</td>
#     </tr>
#     <tr>
#       <th id="T_3f70d_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_3f70d_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_3f70d_row3_col1" class="data row3 col1" >0.9917</td>
#       <td id="T_3f70d_row3_col2" class="data row3 col2" >0.9992</td>
#       <td id="T_3f70d_row3_col3" class="data row3 col3" >0.9917</td>
#       <td id="T_3f70d_row3_col4" class="data row3 col4" >0.9927</td>
#       <td id="T_3f70d_row3_col5" class="data row3 col5" >0.9916</td>
#       <td id="T_3f70d_row3_col6" class="data row3 col6" >0.9869</td>
#       <td id="T_3f70d_row3_col7" class="data row3 col7" >0.9874</td>
#       <td id="T_3f70d_row3_col8" class="data row3 col8" >0.1550</td>
#     </tr>
#     <tr>
#       <th id="T_3f70d_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_3f70d_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_3f70d_row4_col1" class="data row4 col1" >0.9917</td>
#       <td id="T_3f70d_row4_col2" class="data row4 col2" >0.9995</td>
#       <td id="T_3f70d_row4_col3" class="data row4 col3" >0.9917</td>
#       <td id="T_3f70d_row4_col4" class="data row4 col4" >0.9927</td>
#       <td id="T_3f70d_row4_col5" class="data row4 col5" >0.9916</td>
#       <td id="T_3f70d_row4_col6" class="data row4 col6" >0.9870</td>
#       <td id="T_3f70d_row4_col7" class="data row4 col7" >0.9875</td>
#       <td id="T_3f70d_row4_col8" class="data row4 col8" >0.1620</td>
#     </tr>
#     <tr>
#       <th id="T_3f70d_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_3f70d_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3f70d_row5_col1" class="data row5 col1" >0.9875</td>
#       <td id="T_3f70d_row5_col2" class="data row5 col2" >0.9998</td>
#       <td id="T_3f70d_row5_col3" class="data row5 col3" >0.9875</td>
#       <td id="T_3f70d_row5_col4" class="data row5 col4" >0.9889</td>
#       <td id="T
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_88710" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88710_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_88710_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_88710_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_88710_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_88710_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_88710_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_88710_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_88710_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88710_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88710_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_88710_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_88710_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_88710_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_88710_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_88710_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_88710_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_88710_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['bill_length_mm', 'bill_depth_mm',
#                                               'flipper_length_mm',
#                                               'body_mass_g'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,...
#                   TransformerWrapper(exclude=None, include=['island'],
#                                      transformer=OneHotEncoder(cols=['island'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LinearDiscriminantAnalysis(covariance_estimator=None,
#                                              n_components=None, priors=None,
#                                              shrinkage=None, solver='svd',
#                                              store_covariance=False,
#                                              tol=0.0001))],
#           verbose=False),
#  'exp3_multifeature_model.pkl')
